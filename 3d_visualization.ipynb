# %%
import json
import pandas as pd

# Load JSON data
with open('Data.json', 'r') as file:
    data = json.load(file)

# Process the data (assuming 'geoNotesList' is a key in your JSON data)
df = pd.json_normalize(data['geoNotesList'])

# Generate the HTML content
html_content = f"""
<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <title>Display buildings in 3D</title>
    <!-- Ensure proper rendering and touch zooming on mobile devices -->
    <meta
      name="viewport"
      content="initial-scale=1, maximum-scale=1, user-scalable=no"
    />
    <!-- Google Icons for enhanced visual elements -->
    <link
      rel="stylesheet"
      href="https://fonts.googleapis.com/css2?family=Material+Symbols+Outlined:opsz,wght,FILL,GRAD@20..48,100..700,0..1,-50..200"
    />
    <!-- External stylesheet link for custom styles -->
    <link rel="stylesheet" href="your_styles.css" />
    <!-- Mapbox GL JS library for rendering interactive maps -->
    <script src="https://api.mapbox.com/mapbox-gl-js/v2.14.1/mapbox-gl.js"></script>
  </head>

  <body>
    <!-- Navigation bar for the application -->ste
    <nav id="navBar">
      <h2>
        MystoryMaps<span class="material-symbols-outlined">note_stack</span>
      </h2>
    </nav>ds

    <!-- Sidecar for notes beside the map -->
    <div id="sidecar">
      <section class="hidden" id="startPage">
        <h2>
          MystoryMaps<span class="material-symbols-outlined">note_stack</span>
        </h2>
      </section>
      <!-- Container for the Mapbox map -->
      <div id="map"></div>
    </div>

    <!-- Custom JavaScript for the Mapbox implementation -->
    <script>
      const geoNotesList = {json.dumps(df.to_dict(orient='records'))};
    </script>
    <script src="myStoryMap3D.js"></script>
  </body>
</html>
"""

# Write the HTML content to a file
with open('output.html', 'w') as file:
    file.write(html_content)
